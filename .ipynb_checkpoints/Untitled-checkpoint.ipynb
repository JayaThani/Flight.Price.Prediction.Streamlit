# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
train_df=pd.read_excel('Data_Train.xlsx')
test_df=pd.read_excel('Test_set.xlsx')

# %%
train_df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
test_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
df=train_df.append(test_df, sort=False)
# Out:
# C:\Users\91900\AppData\Local\Temp\ipykernel_18412\1729203120.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=train_df.append(test_df, sort=False)

# %%
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
df['Price'].fillna(df['Price'].mean(),inplace=True)

# %%
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df['Price']=df['Price'].astype('int')

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Price               int32
# dtype: object

# %%
df=df.drop('Additional_Info',axis=1)

# %%
df['Total_Stops']=df['Total_Stops'].replace('non-stop','0 stop')

# %%
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  Price
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m      0 stop   3897
# ...

# %%
df['stop']=df['Total_Stops'].str.split(' ').str[0]

# %%
df=df.drop(['Total_Stops'],axis=1)

# %%
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration  Price stop
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m   3897    0
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m   7662    2
# ...

# %%
df['duration_hr']=df['Duration'].str.split(' ').str[0]

# %%
df['dur_hr']=df['duration_hr'].str[0]

# %%
df=df.drop(['duration_hr'],axis=1)

# %%
df['duration_m']=df['Duration'].str.split(' ').str[1]

# %%
df['dur_m']=df['duration_m'].str[0]

# %%
df['dur_m'].fillna('0',inplace=True)

# %%
df=df.drop(['duration_m'],axis=1)

# %%
df=df.drop(['Duration'],axis=1)

# %%
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time  Price stop dur_hr dur_m
# 0                 BLR → DEL    22:20  01:10 22 Mar   3897    0      2     5
# ...

# %%
df['dur_hr']=df['dur_hr'].astype('int')

# %%
df['dur_m']=df['dur_m'].astype('int')

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Price               int32
# stop                int32
# dur_hr              int32
# dur_m               int32
# dtype: object

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Price              0
# stop               0
# dur_hr             0
# dur_m              0
# dtype: int64

# %%
df['route5'].fillna('None',inplace=True)

# %%
df['year']=df['year'].astype('int')

# %%
df
# Out:
#                 Airline    Source Destination                  Route  Price  \
# 0                IndiGo  Banglore   New Delhi              BLR → DEL   3897
# 1             Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7662
# 2           Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  13882
# 3                IndiGo   Kolkata    Banglore        CCU → NAG → BLR   6218
# 4                IndiGo  Banglore   New Delhi        BLR → NAG → DEL  13302
# ...                 ...       ...         ...                    ...    ...
# 2666          Air India   Kolkata    Banglore        CCU → DEL → BLR   9087
# 2667             IndiGo   Kolkata    Banglore              CCU → BLR   9087
# 2668        Jet Airways     Delhi      Cochin        DEL → BOM → COK   9087
# 2669          Air India     Delhi      Cochin        DEL → BOM → COK   9087
# 2670  Multiple carriers     Delhi      Cochin        DEL → BOM → COK   9087
#
# ...

# %%
df['route5']=df['Route'].str.split('→').str[4]

# %%
df=df.drop(['Route'],axis=1)

# %%
df
# Out:
#                 Airline    Source Destination  Price  stop  dur_hr  dur_m  \
# 0                IndiGo  Banglore   New Delhi   3897     0       2      5
# 1             Air India   Kolkata    Banglore   7662     2       7      2
# 2           Jet Airways     Delhi      Cochin  13882     2       1      0
# 3                IndiGo   Kolkata    Banglore   6218     1       5      2
# 4                IndiGo  Banglore   New Delhi  13302     1       4      4
# ...                 ...       ...         ...    ...   ...     ...    ...
# 2666          Air India   Kolkata    Banglore   9087     1       2      5
# 2667             IndiGo   Kolkata    Banglore   9087     0       2      3
# 2668        Jet Airways     Delhi      Cochin   9087     1       6      3
# 2669          Air India     Delhi      Cochin   9087     1       1      1
# 2670  Multiple carriers     Delhi      Cochin   9087     1       1      2
#
#       arrival_hr  arrival_min  dep_hr  dep_min  date  month  year route1  \
# ...

# %%
df.dtypes
# Out:
# Airline        int32
# Source         int32
# Destination    int32
# Price          int32
# stop           int32
# dur_hr         int32
# dur_m          int32
# arrival_hr     int32
# arrival_min    int32
# dep_hr         int32
# dep_min        int32
# date           int32
# month          int32
# year           int32
# route1         int32
# route2         int32
# route3         int32
# route4         int32
# route5         int32
# dtype: object

# %%
df.isnull().sum()
# Out:
# Airline        0
# Source         0
# Destination    0
# Price          0
# stop           0
# dur_hr         0
# dur_m          0
# arrival_hr     0
# arrival_min    0
# dep_hr         0
# dep_min        0
# date           0
# month          0
# year           0
# route1         0
# route2         0
# route3         0
# route4         0
# route5         0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df['route5']=encoder.fit_transform(df['route5'])

# %%
df
# Out:
#       Airline  Source  Destination  Price  stop  dur_hr  dur_m  arrival_hr  \
# 0           3       0            5   3897     0       2      5           1
# 1           1       3            0   7662     2       7      2          13
# 2           4       2            1  13882     2       1      0           4
# 3           3       3            0   6218     1       5      2          23
# 4           3       0            5  13302     1       4      4          21
# ...       ...     ...          ...    ...   ...     ...    ...         ...
# 2666        1       3            0   9087     1       2      5          20
# 2667        3       3            0   9087     0       2      3          16
# 2668        4       2            1   9087     1       6      3           4
# 2669        1       2            1   9087     1       1      1          19
# 2670        6       2            1   9087     1       1      2          19
#
# ...

# %%
train_df=df[0:10683]
